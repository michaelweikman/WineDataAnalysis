# %%
# Importing Libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import os
import random

from scipy.stats import linregress

# %%
#Kaggle cmd will download zip to current file directory -kaggle.json in User folder .kaggle folder
# !kaggle datasets download -d zynicide/wine-reviews --force -p ../Resources
# Out:
# ...
#  92%|███████████████████████████████████   | 47.0M/50.9M [00:01<00:00, 44.0MB/s]
# 100%|██████████████████████████████████████| 50.9M/50.9M [00:01<00:00, 36.1MB/s]

# %%
#Unzip Kaggle Data
import zipfile

Dataset = "wine-reviews"

# Will unzip the files so that you can see them..
with zipfile.ZipFile(f"../Resources/{Dataset}.zip","r") as z:
    z.extractall("../Resources")

# %%
# Reading csv and cleaning column names
df = pd.read_csv('../Resources/winemag-data-130k-v2.csv')
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
# pandas drop a column with drop function
df.drop(['taster_twitter_handle','taster_name'], axis=1, inplace=True)

# %%
country = df['country'].value_counts()
country1 = country.iloc[0:5]

# %%
price = df['price'].value_counts()
price1 = price.iloc[0:5]

# %%
region = df['region_1'].value_counts()
region1 = region.iloc[0:5]

# %%
country1.plot(kind='barh')

# %%
price1.plot(kind='line')

# %%
price1.plot(kind='barh')

# %%
region1.plot(kind='barh')

# %%
# The maximum x value for our chart will be 100
x_limit = 100

# List of values from 0 to 100 each value being 1 greater than the last
x_axis = np.arange(0, x_limit, 1)

# Create a random array of data that we will use for our y values
data = [random.random() for value in x_axis]

# %%
# Group by Country and Different regions

grouped_df = df.groupby(['country'])

# The object returned is a "GroupBy" object and cannot be viewed normally...
print(grouped_df)

# In order to be visualized, a data function must be used...
grouped_df.count().head(10)
# Out:
# ...
#                         description  designation  points  price  province  \
# country
# Argentina                      3800         2902    3800   3756      3800
# Armenia                           2            2       2      2         2
# Australia                      2329         1640    2329   2294      2329
# Austria                        3345         2825    3345   2799      3345
# Bosnia and Herzegovina            2            1       2      2         2
# Brazil                           52           51      52     47        52
# Bulgaria                        141           93     141    141       141
# Canada                          257          179     257    254       257
# Chile                          4472         3879    4472   4416      4472
# China                             1            1       1      1         1
#
#                         region_1  region_2  title  variety  winery
# country
# Argentina                   3747         0   3800     3800    3800
# ...

# %%
grouped_df = df.groupby(['region_1'])

# The object returned is a "GroupBy" object and cannot be viewed normally...
print(grouped_df)

# In order to be visualized, a data function must be used...
grouped_df.count().head(10)
# Out:
# ...
#                            country  description  designation  points  price  \
# region_1
# Abruzzo                          6            6            5       6      6
# Adelaida District              110          110           91     110    110
# Adelaide                        16           16           15      16     16
# Adelaide Hills                 107          107           66     107    105
# Adelaide Plains                  4            4            0       4      4
# Aglianico d'Irpinia              1            1            0       1      1
# Aglianico del Beneventano        2            2            2       2      2
# Aglianico del Taburno           13           13           11      13     11
# Aglianico del Vulture           90           90           74      90     74
# Agrelo                          50           50           48      50     50
#
#                            province  region_2  title  variety  winery
# region_1
# ...

# %%
grouped_df = df.groupby(['region_2'])

# The object returned is a "GroupBy" object and cannot be viewed normally...
print(grouped_df)

# In order to be visualized, a data function must be used...
grouped_df.count().head(10)
# Out:
# ...
#                   country  description  designation  points  price  province  \
# region_2
# California Other     2663         2663         1261    2663   2661      2663
# Central Coast       11065        11065         7902   11065  10975     11065
# Central Valley       1062         1062          678    1062   1058      1062
# Columbia Valley      8103         8103         5572    8103   8058      8103
# Finger Lakes         1777         1777         1232    1777   1768      1777
# Long Island           680          680          471     680    677       680
# Napa                 6814         6814         4207    6814   6804      6814
# Napa-Sonoma          1169         1169          774    1169   1169      1169
# New York Other        231          231          164     231    231       231
# North Coast           584          584          376     584    583       584
#
#                   region_1  title  variety  winery
# region_2
# ...

# %%
#Dispersion of points across prices betweeen 0 - 150$
df_price = df.groupby('price').count()
df_price_only = pd.DataFrame(df_price[df_price['country'] > 100]['country']).rename(columns={'country':'Data Points'})
df_price_only.plot(kind='line')
plt.title('Dispersion of points across prices betweeen 0 - 150$')
plt.show()

# %%
df_price_vs_rating = df[df['price'] <= 150][['price', 'points']].dropna(how='any')

#Decided to use mean points as a comparison value because the point data value is too condensed and skews the graph
price_mean_points_df = df_price_vs_rating.sort_values(by='price', ascending='False').groupby('price').mean()
price_mean_points_df.plot()
plt.ylabel('points')
plt.title('Mean Points (grouped by price) vs. Price')
plt.show()

# %%
#Grouping by top 5 country's and doing price analysis against each
#Grabbing list for filter
top_five_df = df[['country', 'price', 'points']].dropna(how='any')
top_five_df = top_five.groupby('country').max().sort_values(by='points', ascending=False).reset_index()
top_five_list = list(top_five_df.iloc[0:5, 0])
top_five_df = df[df['country'].isin(top_five_list)].dropna(subset=['price', 'points'],how='any')
print(top_five_list)
# Out:
# ['US', 'France', 'Italy', 'Spain', 'Portugal']

# %%
#Seperate country's into data frames
us_df = top_five_df[top_five_df['country'] == 'US']
france_df = top_five_df[top_five_df['country'] == 'France']
italy_df = top_five_df[top_five_df['country'] == 'Italy']
spain_df = top_five_df[top_five_df['country'] == 'Spain']
portugal_df = top_five_df[top_five_df['country'] == 'Portugal']

# %%
#US Data
us_group_price = us_df[['price', 'points']]
x_values = us_group_price['price']
y_values = us_group_price['points']
(slope, intercenpt, rvalue, pvalue, stderr) = linregress(x_values, y_values)
print(rvalue)
plt.scatter(x_values, y_values)
# Out:
# 0.45307886452249674

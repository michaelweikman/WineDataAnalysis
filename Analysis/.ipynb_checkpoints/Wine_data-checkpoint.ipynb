# %%
# %matplotlib notebook

# %%
# Importing Libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import os
import random

from scipy.stats import linregress

# %%
#Kaggle cmd will download zip to current file directory -kaggle.json in User folder .kaggle folder
# !kaggle datasets download -d zynicide/wine-reviews --force -p ../Resources
# Out:
# Downloading wine-reviews.zip to ../Resources
#   0%|          | 0.00/50.9M [00:00<?, ?B/s]
#   2%|1         | 1.00M/50.9M [00:00<00:17, 3.01MB/s]
#   4%|3         | 2.00M/50.9M [00:00<00:14, 3.44MB/s]
#   6%|5         | 3.00M/50.9M [00:00<00:12, 4.03MB/s]
#   8%|7         | 4.00M/50.9M [00:00<00:10, 4.58MB/s]
#  10%|9         | 5.00M/50.9M [00:01<00:10, 4.79MB/s]
#  12%|#1        | 6.00M/50.9M [00:01<00:08, 5.50MB/s]
#  14%|#3        | 7.00M/50.9M [00:01<00:09, 4.64MB/s]
#  16%|#5        | 8.00M/50.9M [00:01<00:08, 5.11MB/s]
#  18%|#7        | 9.00M/50.9M [00:01<00:07, 5.50MB/s]
#  20%|#9        | 10.0M/50.9M [00:01<00:07, 5.67MB/s]
#  22%|##1       | 11.0M/50.9M [00:02<00:07, 5.65MB/s]
#  24%|##3       | 12.0M/50.9M [00:02<00:07, 5.78MB/s]
#  26%|##5       | 13.0M/50.9M [00:02<00:06, 6.37MB/s]
#  28%|##7       | 14.0M/50.9M [00:02<00:06, 6.29MB/s]
#  29%|##9       | 15.0M/50.9M [00:02<00:06, 6.17MB/s]
#  31%|###1      | 16.0M/50.9M [00:02<00:05, 6.51MB/s]
#  33%|###3      | 17.0M/50.9M [00:03<00:05, 6.57MB/s]
#  35%|###5      | 18.0M/50.9M [00:03<00:05, 6.41MB/s]
#  37%|###7      | 19.0M/50.9M [00:03<00:05, 5.96MB/s]
#  39%|###9      | 20.0M/50.9M [00:03<00:04, 6.50MB/s]
#  41%|####1     | 21.0M/50.9M [00:03<00:04, 6.38MB/s]
#  43%|####3     | 22.0M/50.9M [00:03<00:04, 6.12MB/s]
#  45%|####5     | 23.0M/50.9M [00:04<00:04, 6.47MB/s]
#  47%|####7     | 24.0M/50.9M [00:04<00:04, 6.35MB/s]
#  49%|####9     | 25.0M/50.9M [00:04<00:04, 6.46MB/s]
#  51%|#####1    | 26.0M/50.9M [00:04<00:03, 6.53MB/s]
#  53%|#####3    | 27.0M/50.9M [00:04<00:03, 6.40MB/s]
#  55%|#####5    | 28.0M/50.9M [00:04<00:03, 6.30MB/s]
#  57%|#####7    | 29.0M/50.9M [00:05<00:03, 6.07MB/s]
#  59%|#####8    | 30.0M/50.9M [00:05<00:03, 6.08MB/s]
#  61%|######    | 31.0M/50.9M [00:05<00:03, 6.63MB/s]
#  63%|######2   | 32.0M/50.9M [00:05<00:03, 6.46MB/s]
#  65%|######4   | 33.0M/50.9M [00:05<00:02, 6.35MB/s]
#  67%|######6   | 34.0M/50.9M [00:05<00:02, 6.64MB/s]
#  69%|######8   | 35.0M/50.9M [00:06<00:02, 6.66MB/s]
#  71%|#######   | 36.0M/50.9M [00:06<00:02, 6.48MB/s]
#  73%|#######2  | 37.0M/50.9M [00:06<00:02, 5.71MB/s]
#  77%|#######6  | 39.0M/50.9M [00:06<00:01, 6.23MB/s]
#  79%|#######8  | 40.0M/50.9M [00:06<00:01, 6.19MB/s]
#  81%|########  | 41.0M/50.9M [00:07<00:01, 6.34MB/s]
#  83%|########2 | 42.0M/50.9M [00:07<00:01, 6.64MB/s]
#  85%|########4 | 43.0M/50.9M [00:07<00:01, 6.38MB/s]
#  87%|########6 | 44.0M/50.9M [00:07<00:01, 6.11MB/s]
#  88%|########8 | 45.0M/50.9M [00:07<00:01, 5.37MB/s]
#  92%|#########2| 47.0M/50.9M [00:08<00:00, 6.00MB/s]
#  94%|#########4| 48.0M/50.9M [00:08<00:00, 6.17MB/s]
#  96%|#########6| 49.0M/50.9M [00:08<00:00, 6.31MB/s]
#  98%|#########8| 50.0M/50.9M [00:08<00:00, 6.24MB/s]
# 100%|##########| 50.9M/50.9M [00:08<00:00, 6.11MB/s]
# 100%|##########| 50.9M/50.9M [00:08<00:00, 6.11MB/s]

# %%
#Unzip Kaggle Data
import zipfile

Dataset = "wine-reviews"

# Will unzip the files so that you can see them..
with zipfile.ZipFile(f"../Resources/{Dataset}.zip","r") as z:
    z.extractall("../Resources")

# %%
# Reading csv and cleaning column names
df = pd.read_csv('../Resources/winemag-data-130k-v2.csv')
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
# pandas drop a column with drop function
df.drop(['taster_twitter_handle','taster_name'], axis=1, inplace=True)

# %%
country = df['country'].value_counts()
country1 = country.iloc[0:4]

# %%
price = df['price'].value_counts()
price1 = price.iloc[0:4]

# %%
region = df['region_1'].value_counts()
region1 = region.iloc[0:4]

# %%
country1.plot(kind='bar', color=['red', 'orange', 'green', 'blue'])

# Give our chart some labels and a tile
plt.title("Wine Base on its Countries")
plt.xlabel("Prices")
plt.ylabel("Countries")
plt.savefig(f"../Analysis/png_output/wine_base_on_countries")
plt.show()

# %%
price1.plot(kind='bar', color=['red', 'orange', 'green', 'blue'])
country1.plot(kind='bar', color=['red', 'orange', 'green', 'blue'])

# Give our chart some labels and a tile
plt.title("Wine Base on Country & Price")
plt.xlabel("Countries")
plt.ylabel("Price")
plt.savefig(f"../Analysis/png_output/country_vs_price")
plt.show()

# %%
region1.plot(kind='bar', color=['red', 'orange', 'green', 'blue'])
country1.plot(kind='bar', color=['red', 'orange', 'green', 'blue'])

# Give our chart some labels and a tile
plt.title("Wine base on Countries & Region")
plt.xlabel("Prices")
plt.ylabel("Countries")
plt.savefig(f"../Analysis/png_output/country_vs_regions")
plt.show()

# %%
price1.plot(kind ='barh', color=['red', 'orange', 'green', 'blue'])
#region1.plot(kind = 'barh', color=['red', 'orange', 'green', 'blue'])

# Give our chart some labels and a tile
plt.title("Wine on Price vs Regions")
plt.xlabel("Prices")
plt.ylabel("Regions")
plt.savefig(f"../Analysis/png_output/Price_regions")
plt.show()

# %%
# The maximum x value for our chart will be 50000
x_limit = 50000

# List of values from 0 to 50000 each value being 1 greater than the last
x_axis = np.arange(0, x_limit, 1)

# Create a random array of data that we will use for our y values
data = [random.random() for value in x_axis]

# %%
# Group by Country and Different regions

grouped_df = df.groupby(['country'])

# The object returned is a "GroupBy" object and cannot be viewed normally...
print(grouped_df)

# In order to be visualized, a data function must be used...
grouped_df.count().head()
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001A950901948>
#                         description  designation  points  price  province  \
# country
# Argentina                      3800         2902    3800   3756      3800
# Armenia                           2            2       2      2         2
# Australia                      2329         1640    2329   2294      2329
# Austria                        3345         2825    3345   2799      3345
# Bosnia and Herzegovina            2            1       2      2         2
#
#                         region_1  region_2  title  variety  winery
# country
# Argentina                   3747         0   3800     3800    3800
# Armenia                        0         0      2        2       2
# Australia                   2327         0   2329     2329    2329
# Austria                        0         0   3345     3345    3345
# Bosnia and Herzegovina         0         0      2        2       2

# %%
grouped_df = df.groupby(['region_1'])

# The object returned is a "GroupBy" object and cannot be viewed normally...
print(grouped_df)

# In order to be visualized, a data function must be used...
grouped_df.count().head()
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001A950939048>
#                    country  description  designation  points  price  province  \
# region_1
# Abruzzo                  6            6            5       6      6         6
# Adelaida District      110          110           91     110    110       110
# Adelaide                16           16           15      16     16        16
# Adelaide Hills         107          107           66     107    105       107
# Adelaide Plains          4            4            0       4      4         4
#
#                    region_2  title  variety  winery
# region_1
# Abruzzo                   0      6        6       6
# Adelaida District       110    110      110     110
# Adelaide                  0     16       16      16
# Adelaide Hills            0    107      107     107
# Adelaide Plains           0      4        4       4

# %%
grouped_df = df.groupby(['region_2'])

# The object returned is a "GroupBy" object and cannot be viewed normally...
print(grouped_df)

# In order to be visualized, a data function must be used...
grouped_df.count().head()
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001A950923E48>
#                   country  description  designation  points  price  province  \
# region_2
# California Other     2663         2663         1261    2663   2661      2663
# Central Coast       11065        11065         7902   11065  10975     11065
# Central Valley       1062         1062          678    1062   1058      1062
# Columbia Valley      8103         8103         5572    8103   8058      8103
# Finger Lakes         1777         1777         1232    1777   1768      1777
#
#                   region_1  title  variety  winery
# region_2
# California Other      2663   2663     2663    2663
# Central Coast        11065  11065    11065   11065
# Central Valley        1062   1062     1062    1062
# Columbia Valley       8103   8103     8103    8103
# Finger Lakes          1777   1777     1777    1777

# %%
group_country = pd.DataFrame(df.groupby('country')['region_1'].count())
group_country.sort_values(by='region_1', ascending=False)
group_country.head()
# Out:
#                         region_1
# country
# Argentina                   3747
# Armenia                        0
# Australia                   2327
# Austria                        0
# Bosnia and Herzegovina         0

# %%
# Labels for the sections of our pie chart
labels = ["US", "France", "Italy", "Spain"]

# The values of each section of the pie chart
sizes = [54226, 22017, 19513, 6637]

# The colors of each section of the pie chart
colors = ["red", "orange", "lightcoral", "lightskyblue", "Yellow", "Purple","Green"]

# Tells matplotlib to seperate the "Humans" section from the others
explode = (0.1, 0, 0, 0)

# %%
# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.savefig(f"../Analysis/png_output/piechartcountries")
plt.show()

# %%
group_country = pd.DataFrame(df.groupby('country')['price'].count())
group_country.sort_values(by='price', ascending=False)
# Out:
#                         price
# country
# US                      54265
# France                  17776
# Italy                   16914
# Spain                    6573
# Portugal                 4875
# Chile                    4416
# Argentina                3756
# Austria                  2799
# Australia                2294
# Germany                  2120
# New Zealand              1378
# South Africa             1293
# Israel                    489
# Greece                    461
# Canada                    254
# Hungary                   145
# Bulgaria                  141
# Romania                   120
# Uruguay                   109
# Turkey                     90
# Georgia                    84
# Slovenia                   80
# Croatia                    71
# Mexico                     70
# England                    69
# Moldova                    59
# Brazil                     47
# Lebanon                    35
# Morocco                    28
# Peru                       16
# Ukraine                    14
# Macedonia                  12
# Serbia                     12
# Czech Republic             12
# Cyprus                     11
# India                       9
# Switzerland                 7
# Luxembourg                  6
# Armenia                     2
# Bosnia and Herzegovina      2
# China                       1
# Slovakia                    1
# Egypt                       0

# %%
# Labels for the sections of our pie chart
labels = ["US", "France", "Italy", "Spain", "Portugal"]

# The values of each section of the pie chart
sizes = [54265, 17776, 16917, 6573, 4875]

# The colors of each section of the pie chart
colors = ["red", "orange", "lightcoral", "lightskyblue", "Yellow", "Purple","Green"]

# Tells matplotlib to seperate the "Humans" section from the others
explode = (0.1, 0, 0, 0, 0)

# %%
# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.savefig(f"../Analysis/png_output/topwinecountries")
plt.show()

# %%
df_price = df.groupby('price').count()
df_price[df_price['country'] > 100]
# Out:
#        country  description  designation  points  province  region_1  \
# price
# 6.0        118          120           64     120       118        71
# 7.0        433          433          266     433       433       235
# 8.0        892          892          531     892       892       550
# 9.0       1339         1339          812    1339      1339       806
# 10.0      3439         3439         2077    3439      3439      2331
# ...        ...          ...          ...     ...       ...       ...
# 125.0      328          328          276     328       328       314
# 130.0      141          141          112     141       141       136
# 135.0      110          110           99     110       110       109
# 140.0      112          112           95     112       112       111
# 150.0      239          239          202     239       239       227
#
#        region_2  title  variety  winery
# price
# 6.0          24    120      120     120
# 7.0         111    433      433     433
# 8.0         246    892      892     892
# 9.0         220   1339     1339    1339
# 10.0        803   3439     3439    3439
# ...         ...    ...      ...     ...
# 125.0       221    328      328     328
# 130.0        29    141      141     141
# 135.0        64    110      110     110
# 140.0        34    112      112     112
# 150.0       127    239      239     239
#
# [79 rows x 10 columns]

# %%
df_price = df.groupby('price').count()
df_price_only = pd.DataFrame(df_price[df_price['country'] > 100] ['country']).rename(columns={'country':'Data Points'})
df_price_only.plot(kind = 'line', color=['purple'])
plt.savefig(f"../Analysis/png_output/regionpricedatapoints")
plt.show()

# %%
group_country = pd.DataFrame(df.groupby('country')['region_1'].count())
group_country.sort_values(by='region_1', ascending=False)
# Out:
#                         region_1
# country
# US                         54226
# France                     22017
# Italy                      19513
# Spain                       6637
# Argentina                   3747
# Australia                   2327
# Canada                       257
# Turkey                         0
# Macedonia                      0
# Mexico                         0
# Moldova                        0
# Morocco                        0
# New Zealand                    0
# Peru                           0
# Portugal                       0
# Switzerland                    0
# Romania                        0
# Serbia                         0
# Luxembourg                     0
# Slovenia                       0
# South Africa                   0
# Ukraine                        0
# Slovakia                       0
# Israel                         0
# Lebanon                        0
# Cyprus                         0
# Austria                        0
# Bosnia and Herzegovina         0
# Brazil                         0
# Bulgaria                       0
# Chile                          0
# China                          0
# Croatia                        0
# Czech Republic                 0
# Armenia                        0
# Egypt                          0
# England                        0
# Georgia                        0
# Germany                        0
# Greece                         0
# Hungary                        0
# India                          0
# Uruguay                        0

# %%
group_country.plot.scatter(x='region_1', y='region_1', title='Wines by the region')
plt.show()

# %%
country1.plot.hist(subplots=True, layout=(2,2), figsize=(10, 10), bins=20)
plt.show()

# %%
group_countryv = pd.DataFrame(df.groupby('country')['variety'].count())
group_countryv.sort_values(by='variety', ascending=False)
# Out:
#                         variety
# country
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4471
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# Peru                         16
# Ukraine                      14
# Macedonia                    12
# Serbia                       12
# Czech Republic               12
# Cyprus                       11
# India                         9
# Switzerland                   7
# Luxembourg                    6
# Armenia                       2
# Bosnia and Herzegovina        2
# China                         1
# Slovakia                      1
# Egypt                         1

# %%
group_countryv.plot(kind = 'line', color=['green'])
plt.savefig(f"../Analysis/png_output/variety")
plt.show()

# %%
grouped_df.count().head()
# Out:
#                   country  description  designation  points  price  province  \
# region_2
# California Other     2663         2663         1261    2663   2661      2663
# Central Coast       11065        11065         7902   11065  10975     11065
# Central Valley       1062         1062          678    1062   1058      1062
# Columbia Valley      8103         8103         5572    8103   8058      8103
# Finger Lakes         1777         1777         1232    1777   1768      1777
#
#                   region_1  title  variety  winery
# region_2
# California Other      2663   2663     2663    2663
# Central Coast        11065  11065    11065   11065
# Central Valley        1062   1062     1062    1062
# Columbia Valley       8103   8103     8103    8103
# Finger Lakes          1777   1777     1777    1777

# %%
group_region = pd.DataFrame(df.groupby('region_2')['points'].count())
group_region.sort_values(by='points', ascending=False)
# Out:
#                    points
# region_2
# Central Coast       11065
# Sonoma               9028
# Columbia Valley      8103
# Napa                 6814
# Willamette Valley    3423
# California Other     2663
# Finger Lakes         1777
# Sierra Foothills     1462
# Napa-Sonoma          1169
# Central Valley       1062
# Southern Oregon       917
# Oregon Other          727
# Long Island           680
# North Coast           584
# Washington Other      534
# South Coast           272
# New York Other        231

# %%
group_region.plot(kind ='barh', color=['red', 'orange', 'green', 'blue'])

# Give our chart some labels and a tile
plt.title("Wine Points for Region 2")
plt.xlabel("Points")
plt.ylabel("Regions")
plt.savefig(f"../Analysis/png_output/winepointsregion2")
plt.show()
